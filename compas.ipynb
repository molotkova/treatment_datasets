# %% [markdown]
# Some notes from https://www.propublica.org/article/how-we-analyzed-the-compas-recidivism-algorithm:
# * Black defendants were often predicted to be at a higher risk of recidivism than they actually were.

# %%
import pandas as pd

# %%
url_two_years = "https://raw.githubusercontent.com/propublica/compas-analysis/refs/heads/master/compas-scores-two-years.csv"
df_two_years = pd.read_csv(url_two_years)

# %%
url_raw = "https://raw.githubusercontent.com/propublica/compas-analysis/refs/heads/master/compas-scores-raw.csv"
df_raw = pd.read_csv(url_raw)

# %%
url_two_years_violent = "https://raw.githubusercontent.com/propublica/compas-analysis/refs/heads/master/compas-scores-two-years-violent.csv"
df_two_years_violent = pd.read_csv(url_two_years_violent)

# %%
df_two_years.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1947-04-18   69  Greater than 45             Other  ...               1
# 1  1982-01-22   34          25 - 45  African-American  ...               1
# 2  1991-05-14   24     Less than 25  African-American  ...               3
# 3  1993-01-21   23     Less than 25  African-American  ...               6
# 4  1973-01-22   43          25 - 45             Other  ...               1
#
# ...

# %%
df_two_years.shape, df_raw.shape
# Out:
# ((7214, 53), (60843, 28))

# %%
df_raw.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ...  RecSupervisionLevel  \
# 0          Male        Caucasian    12/05/92  ...                    1
# 1          Male        Caucasian    12/05/92  ...                    1
# 2          Male        Caucasian    12/05/92  ...                    1
# 3          Male        Caucasian    09/16/84  ...                    1
# 4          Male        Caucasian    09/16/84  ...                    1
#
# ...

# %%
df_two_years.columns
# Out:
# Index(['id', 'name', 'first', 'last', 'compas_screening_date', 'sex', 'dob',
#        'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score',
#        'juv_misd_count', 'juv_other_count', 'priors_count',
#        'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number',
#        'c_offense_date', 'c_arrest_date', 'c_days_from_compas',
#        'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_case_number',
#        'r_charge_degree', 'r_days_from_arrest', 'r_offense_date',
#        'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid',
#        'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
#        'vr_offense_date', 'vr_charge_desc', 'type_of_assessment',
#        'decile_score.1', 'score_text', 'screening_date',
#        'v_type_of_assessment', 'v_decile_score', 'v_score_text',
#        'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1',
#        'start', 'end', 'event', 'two_year_recid'],
#       dtype='object')

# %%
df_raw.columns
# Out:
# Index(['Person_ID', 'AssessmentID', 'Case_ID', 'Agency_Text', 'LastName',
#        'FirstName', 'MiddleName', 'Sex_Code_Text', 'Ethnic_Code_Text',
#        'DateOfBirth', 'ScaleSet_ID', 'ScaleSet', 'AssessmentReason',
#        'Language', 'LegalStatus', 'CustodyStatus', 'MaritalStatus',
#        'Screening_Date', 'RecSupervisionLevel', 'RecSupervisionLevelText',
#        'Scale_ID', 'DisplayText', 'RawScore', 'DecileScore', 'ScoreText',
#        'AssessmentType', 'IsCompleted', 'IsDeleted'],
#       dtype='object')

# %%
df_two_years["violent_recid"].isnull().sum()/df_two_years.shape[0]
# Out:
# np.float64(1.0)

# %%
df_raw["DisplayText"].shape
# Out:
# (60843,)

# %%
df_two_years_violent
# Out:
#          id                name    first         last compas_screening_date  \
# 0         1    miguel hernandez   miguel    hernandez            2013-08-14
# 1         3         kevon dixon    kevon        dixon            2013-01-27
# 2         5         marcu brown    marcu        brown            2013-01-13
# 3         6  bouthy pierrelouis   bouthy  pierrelouis            2013-03-26
# 4         7        marsha miles   marsha        miles            2013-11-30
# ...     ...                 ...      ...          ...                   ...
# 4738  10995        raheem smith   raheem        smith            2013-10-20
# 4739  10996       steven butler   steven       butler            2013-11-23
# 4740  10997     malcolm simmons  malcolm      simmons            2014-02-01
# 4741  10999     winston gregory  winston      gregory            2014-01-14
# 4742  11000         farrah jean   farrah         jean            2014-03-09
#
# ...

# %%
len(set(df_two_years.columns.tolist())), len(set(df_two_years_violent.columns.tolist()))
# Out:
# (53, 54)

# %%
set(df_two_years_violent.columns.tolist()) - set(df_two_years.columns.tolist())
# Out:
# {'two_year_recid.1'}

# %%
df_two_years_violent.columns
# Out:
# Index(['id', 'name', 'first', 'last', 'compas_screening_date', 'sex', 'dob',
#        'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score',
#        'juv_misd_count', 'juv_other_count', 'priors_count',
#        'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number',
#        'c_offense_date', 'c_arrest_date', 'c_days_from_compas',
#        'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_case_number',
#        'r_charge_degree', 'r_days_from_arrest', 'r_offense_date',
#        'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid',
#        'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
#        'vr_offense_date', 'vr_charge_desc', 'type_of_assessment',
#        'decile_score.1', 'score_text', 'screening_date',
#        'v_type_of_assessment', 'v_decile_score', 'v_score_text',
#        'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1',
#        'start', 'end', 'event', 'two_year_recid', 'two_year_recid.1'],
# ...

# %%
df_two_years[['violent_recid',
       'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
       'vr_offense_date', 'vr_charge_desc']].sample(10)
# Out:
#       violent_recid  is_violent_recid vr_case_number vr_charge_degree  \
# 2496            NaN                 1  14003856CF10A             (F3)
# 2693            NaN                 0            NaN              NaN
# 2308            NaN                 0            NaN              NaN
# 5446            NaN                 0            NaN              NaN
# 2083            NaN                 1  15004748CF10A             (F3)
# 4717            NaN                 0            NaN              NaN
# 6406            NaN                 0            NaN              NaN
# 2041            NaN                 0            NaN              NaN
# 6520            NaN                 0            NaN              NaN
# 2712            NaN                 0            NaN              NaN
#
#      vr_offense_date                  vr_charge_desc
# 2496      2014-03-19  Aggravated Assault W/Dead Weap
# 2693             NaN                             NaN
# ...

# %%
df_two_years_violent[['violent_recid',
       'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
       'vr_offense_date', 'vr_charge_desc']].sample(10)
# Out:
#       violent_recid  is_violent_recid vr_case_number vr_charge_degree  \
# 3678            NaN                 0            NaN              NaN
# 3220            NaN                 1  14004663CF10A             (F2)
# 4673            NaN                 0            NaN              NaN
# 1894            NaN                 0            NaN              NaN
# 2784            NaN                 0            NaN              NaN
# 2829            NaN                 0            NaN              NaN
# 4407            NaN                 0            NaN              NaN
# 1202            NaN                 0            NaN              NaN
# 636             NaN                 0            NaN              NaN
# 1186            NaN                 0            NaN              NaN
#
#      vr_offense_date                  vr_charge_desc
# 3678             NaN                             NaN
# 3220      2014-04-03  Agg Fleeing/Eluding High Speed
# ...
