# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/propublica/compas-analysis/refs/heads/master/compas-scores-raw.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ...  RecSupervisionLevel  \
# 0          Male        Caucasian    12/05/92  ...                    1
# 1          Male        Caucasian    12/05/92  ...                    1
# 2          Male        Caucasian    12/05/92  ...                    1
# 3          Male        Caucasian    09/16/84  ...                    1
# 4          Male        Caucasian    09/16/84  ...                    1
#
# ...

# %%
from utils import calculate_nan_percentage_of_grouped_features

missing_stat = calculate_nan_percentage_of_grouped_features(df, "data/compas-scores-raw/features.yaml")

# %%
display(missing_stat)
# Out:
#      Category                  Feature  Missing_Count  Missing_Percentage
# 9   Covariate              DateOfBirth              0            0.000000
# 14  Covariate              LegalStatus              0            0.000000
# 13  Covariate                 Language              0            0.000000
# 16  Covariate            MaritalStatus              0            0.000000
# 18  Covariate      RecSupervisionLevel              0            0.000000
# 7   Sensitive            Sex_Code_Text              0            0.000000
# 8   Sensitive         Ethnic_Code_Text              0            0.000000
# 24  Treatment                ScoreText             45            0.073961
# 11  Treatment                 ScaleSet              0            0.000000
# 15  Treatment            CustodyStatus              0            0.000000
# 19  Treatment  RecSupervisionLevelText              0            0.000000
# 22  Treatment                 RawScore              0            0.000000
# ...
