# %%
import pandas as pd

# %%
df = pd.read_csv("data/home-insurance/home_insurance.csv")

# %%
df.shape
# Out:
# (256136, 66)

# %% [markdown]
# ### Most impactful treatment features
# tun tun

# %%
from utils import calculate_nan_percentage_of_grouped_features

missing_stat = calculate_nan_percentage_of_grouped_features(df, "data/home-insurance/features.yaml")

# %%
display(missing_stat)
# Out:
#      Category              Feature  Missing_Count  Missing_Percentage
# 4   Covariate     P1_PT_EMP_STATUS         254354           99.304276
# 6   Covariate             CLERICAL         253192           98.850611
# 43  Covariate    PAYMENT_FREQUENCY         175582           68.550301
# 8   Covariate    RISK_RATED_AREA_B         115260           44.999531
# 12  Covariate    RISK_RATED_AREA_C          75846           29.611613
# 5   Covariate              BUS_USE          67115           26.202877
# 3   Covariate        P1_EMP_STATUS          67115           26.202877
# 26  Covariate             BEDROOMS          67115           26.202877
# 20  Covariate               P1_DOB          67115           26.202877
# 24  Covariate           APPR_ALARM          67115           26.202877
# 25  Covariate           APPR_LOCKS          67115           26.202877
# 30  Covariate               LISTED          67115           26.202877
# ...
